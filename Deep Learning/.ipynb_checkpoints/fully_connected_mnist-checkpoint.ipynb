# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
# Out:
# Using plaidml.keras.backend backend.

# %%
mnist = keras.datasets.mnist.load_data()

# %%
(x_train, y_train), (x_test, y_test) = mnist

# %%
x_train = x_train.reshape(x_train.shape[0], -1).astype("float32")
x_test = x_test.reshape(x_test.shape[0], -1).astype("float32")
x_train /= x_train.max()
x_test /= x_test.max()

# %%
y_train = keras.utils.np_utils.to_categorical(y_train)
y_test = keras.utils.np_utils.to_categorical(y_test)

# %%
input1 = keras.layers.Input(shape=(28*28,))
x = keras.layers.Dense(100, activation="relu")(input1)
x = keras.layer
out = keras.layers.Dense(10, activation='softmax')(x)
model = keras.models.Model(input1, out)

# %%
model.compile(optimizer=keras.optimizers.Adam(0.001), loss="categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 14s 232us/step - loss: 0.2733 - acc: 0.9217 - val_loss: 0.1500 - val_acc: 0.9546
# Epoch 2/10
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.1258 - acc: 0.9624 - val_loss: 0.1071 - val_acc: 0.9667
# Epoch 3/10
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.0881 - acc: 0.9738 - val_loss: 0.0923 - val_acc: 0.9714
# Epoch 4/10
# 60000/60000 [==============================] - 14s 240us/step - loss: 0.0676 - acc: 0.9794 - val_loss: 0.0859 - val_acc: 0.9722
# Epoch 5/10
# 60000/60000 [==============================] - 15s 249us/step - loss: 0.0528 - acc: 0.9839 - val_loss: 0.0853 - val_acc: 0.9758
# Epoch 6/10
# 60000/60000 [==============================] - 15s 243us/step - loss: 0.0436 - acc: 0.9863 - val_loss: 0.0821 - val_acc: 0.9743
# Epoch 7/10
# ...

# %%
predict = np.argmax(model.predict(x_test), axis=1)
for x in range(1, 6):
  sub = 1
  counter = 1
  plt.figure(figsize=(30, 100))
  for i in range((x) * 10, ((x+1) * 10)):
    plt.subplot(1, 10,  counter)
    real_value = str(np.argmax(y_test[i]))
    pred_value = str(predict[i])
    cmap = "Reds" if real_value != pred_value else "Greens"
    plt.imshow(x_test[i].reshape(28,28), cmap=cmap)
    plt.title("r: " + real_value + ' | p: ' + pred_value)
    counter += 1
  plt.show()
